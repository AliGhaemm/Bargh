# %% [markdown]
# <h1>
#     This file predicts all data and add the prediction column to the df and saves it in with_prediction.csv
# </h1>

# %%
import os
import sys

current_dir = os.getcwd()
project_root = current_dir[:current_dir.find("src") - 1]
sys.path.insert(0, project_root)

# %%
from src.models.prediction.prediction import *

csv_read_path = os.path.join(project_root, "data", "processed", "semi_processed.csv")
df = pd.read_csv(csv_read_path, encoding='utf-8')

# %%
normal_models_folder = os.path.join(project_root, "src", "models", "fitted_models", "normal")
turbo_models_folder = os.path.join(project_root, "src", "models", "fitted_models", "turbo")
normal_models = load_models(normal_models_folder)
turbo_models = load_models(turbo_models_folder)

df_selected = select_needed_features(df)

ds_n_c = Data_selector(df_selected)
ds_n_c.df = ds_n_c.df.dropna()
power_plants = ds_n_c.df[['name', 'code']].drop_duplicates()
for row in power_plants.itertuples():
    name, code = row.name, row.code

    df_n_c = ds_n_c.filter_name_code(name, code)

    fs_n_c = Feature_selector(df_n_c, "generation")
    fs_n_c.filter_features(features_to_drop=["name", "code"])
    X, _ = fs_n_c.get_X_and_y()
    
    try:
        normal_model = normal_models[name, code]
        y_pred = normal_model.predict(X)
        df.loc[X.index, "prediction"] = y_pred
    except:
        print(f"No normal model has been found for {name}-{code} unit")

    try:
        turbo_model = turbo_models[name, code]
        y_pred = turbo_model.predict(X)
        df.loc[X.index, "prediction_turbo"] = y_pred
    except:
        print(f"No turbo model has been found for {name}-{code} unit")

csv_output_path = os.path.join(project_root, "data", "processed", "with_prediction.csv")
df.to_csv(csv_output_path)
# Out:
# No turbo model has been found for جنوب اصفهان - چهلستون-G11 unit
# No turbo model has been found for جنوب اصفهان - چهلستون-G12 unit
# No turbo model has been found for جنوب اصفهان - چهلستون-G13 unit
# No turbo model has been found for جنوب اصفهان - چهلستون-G14 unit
# No turbo model has been found for جنوب اصفهان - چهلستون-G15 unit
# No turbo model has been found for جنوب اصفهان - چهلستون-G16 unit
# No turbo model has been found for حافظ-G11 unit
# No turbo model has been found for حافظ-G12 unit
# No turbo model has been found for حافظ-G13 unit
# No turbo model has been found for حافظ-G14 unit
# No turbo model has been found for حافظ-G15 unit
# No turbo model has been found for حافظ-G16 unit
# No turbo model has been found for سبلان-G11 unit
# No turbo model has been found for سبلان-G12 unit
# No turbo model has been found for سبلان-G13 unit
# No turbo model has been found for سبلان-G14 unit
# No turbo model has been found for سبلان-G15 unit
# No turbo model has been found for سبلان-G16 unit
# No turbo model has been found for سیکل ترکیبی ارومیه-G11 unit
# No turbo model has been found for سیکل ترکیبی ارومیه-G12 unit
# No turbo model has been found for سیکل ترکیبی ارومیه-G13 unit
# No turbo model has been found for سیکل ترکیبی ارومیه-G14 unit
# No turbo model has been found for سیکل ترکیبی ارومیه-G15 unit
# No turbo model has been found for سیکل ترکیبی ارومیه-G16 unit
# No turbo model has been found for سیکل ترکیبی یزد-G11 unit
# No turbo model has been found for سیکل ترکیبی یزد-G12 unit
# No normal model has been found for سیکل ترکیبی یزد-G13 unit
# No turbo model has been found for سیکل ترکیبی یزد-G13 unit
# No turbo model has been found for شهدای پیروز - بهبهان-G11 unit
# No turbo model has been found for شهدای پیروز - بهبهان-G12 unit
# No turbo model has been found for عسلویه-G11 unit
# No turbo model has been found for عسلویه-G12 unit
# No turbo model has been found for عسلویه-G13 unit
# No turbo model has been found for عسلویه-G14 unit
# No turbo model has been found for عسلویه-G15 unit
# No turbo model has been found for عسلویه-G16 unit
# No turbo model has been found for پرند-G11 unit
# No turbo model has been found for پرند-G12 unit
# No turbo model has been found for پرند-G13 unit
# No turbo model has been found for پرند-G14 unit
# No turbo model has been found for پرند-G15 unit
# No turbo model has been found for پرند-G16 unit
# No turbo model has been found for گیلان-G11 unit
# No turbo model has been found for گیلان-G12 unit
# No turbo model has been found for گیلان-G13 unit
# No turbo model has been found for گیلان-G14 unit
# No turbo model has been found for گیلان-G15 unit
# No turbo model has been found for گیلان-G16 unit
